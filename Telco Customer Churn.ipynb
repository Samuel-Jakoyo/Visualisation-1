# %%
#import necessary libraries and files
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read the file
telco = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
churn_no = telco[telco['Churn'] == 'No']
churn_yes = telco[telco['Churn'] == 'Yes']

# %% [raw]
# 1a) Which demographic is proven to be most popular with telco brand

# %%
churn_no.groupby(['gender','SeniorCitizen','Partner','Dependents']).count()
# Out:
#                                          customerID  tenure  PhoneService  \
# gender SeniorCitizen Partner Dependents
# Female 0             No      No                 909     909           909
#                              Yes                110     110           110
#                      Yes     No                 482     482           482
#                              Yes                720     720           720
#        1             No      No                 159     159           159
#                              Yes                  2       2             2
#                      Yes     No                 136     136           136
#                              Yes                 31      31            31
# Male   0             No      No                 963     963           963
#                              Yes                168     168           168
#                      Yes     No                 439     439           439
# ...

# %%
churn_yes.groupby(['gender','SeniorCitizen','Partner','Dependents']).count()
# Out:
#                                          customerID  tenure  PhoneService  \
# gender SeniorCitizen Partner Dependents
# Female 0             No      No                 429     429           429
#                              Yes                 32      32            32
#                      Yes     No                 114     114           114
#                              Yes                124     124           124
#        1             No      No                 158     158           158
#                              Yes                  1       1             1
#                      Yes     No                  73      73            73
#                              Yes                  8       8             8
# Male   0             No      No                 418     418           418
#                              Yes                 43      43            43
#                      Yes     No                 128     128           128
# ...

# %% [raw]
# 1b) To increase customer retention, marketing team should target advertisements to who?
# Young male customers without partners

# %% [raw]
# 2a) Which 3 services are contributing to high monthly charge and resulting to customers churning:
# Phone Service
# Online Backup
# Streaming movies

# %%
services = ['PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract']

for service in services:
    plt.gcf().set_size_inches(22,10,forward= True)
    sns.barplot(x= service,y='MonthlyCharges',data = telco,hue='Churn')
    plt.title(service)
    plt.show()

# %% [raw]
# 2b) If telco was to offer phone as standalone service, which contract would encourage customer retention:
# Month to month

# %%
phone_service = churn_no[churn_no['PhoneService'] == 'Yes']

phone_service.groupby('Contract')['Churn'].count()
# Out:
# Contract
# Month-to-month    1997
# One year          1176
# Two year          1489
# Name: Churn, dtype: int64

# %% [raw]
# 3a) What monthly prices will be appropriate for the following packages to keep customers from churnin:
#  i.   Basic: 20
#  ii.  Plus: 60
#  iii. Premium: 80

# %%
plt.gcf().set_size_inches(22,10,forward=True)
sns.distplot(churn_yes['MonthlyCharges'])

# %% [raw]
# 3b) Should the company go strictly paperless for monthly bills as technique for keeping customer and why

# %%
telco.groupby(['PaperlessBilling'])['Churn'].count()
# Out:
# PaperlessBilling
# No     2872
# Yes    4171
# Name: Churn, dtype: int64
